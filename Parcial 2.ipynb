# %%
# Import de libs
import CalculoDistribuciones as CalcDistri

import importlib
import scipy.stats
import numpy as np
import math
importlib.reload(CalcDistri)
# Out:
# <module 'CalculoDistribuciones' from '/Users/fpoblete/UADE/Estadistica General/CalculoDistribuciones.py'>

# %% [markdown]
# # Problema 1En  una  fábrica  textil que  elabora  telas  de  propileno, el  proceso  de  fabricación  produce,  en  condiciones normales de trabajo, 1 falla cada 100m. Cada rollo mide 35my si un rollo tiene alguna falla, se considera defectuoso.

# %% [markdown]
# # a)Calcular el porcentaje de rollos defectuosos.

# %%
round(CalcDistri.Poisson_Calcular_m(1/100,35),4)
# Out:
# 0.35

# %% [markdown]
# # RESULTADO A)

# %%
0.29531*100
# Out:
# 29.531000000000002

# %% [markdown]
# # b)De los rollos defectuosos ¿Qué porcentaje presenta menos de 3fallas?

# %% [markdown]
# # USANDO x <= 0 y x<=2

# %%
round((0.99449-0.70469)/0.29531,4)
# Out:
# 0.9813

# %% [markdown]
# # RESULTADO B)

# %%
round((0.99449-0.70469)/0.29531,4)*100
# Out:
# 98.13

# %% [markdown]
# # USANDO X=1 + X=2

# %%
round((0.24664+0.04316)/0.29531,4)*100
# Out:
# 98.13

# %% [markdown]
# # La fábrica cuenta con máquinas enrolladoras de tela con variador de velocidad y selector del sentido de giro. El tiempo de reparación de estasmáquinas posee distribución exponencial, con media 16minutos.

# %% [markdown]
# # c)Hallar la probabilidad de que el tiempo de reparación sea menor que diez minutos.

# %%
lamb = 1/16
lamb
# Out:
# 0.0625

# %% [markdown]
# # RESULTADO C)

# %%
0.46474
# Out:
# 0.46474

# %% [markdown]
# # d)¿Cuánto tiempo se debe asignar a cada reparación para que la probabilidad de que cualquier tiempo de reparación mayor que el tiempo asignado sea de 0,15?

# %%
30.35392
# Out:
# 30.35392

# %% [markdown]
# # e)Se  seleccionan 8máquinasenrolladorasal  azar  ¿Cuál  es  la  probabilidad  de  que alguna  deellas presente un tiempo de reparacióncomprendido entre 12 minutos y 18 minutos?

# %%
round(0.67535-0.52763,4)
# Out:
# 0.1477

# %%
0.72155
# Out:
# 0.72155

# %% [markdown]
# Screen Shot 2020-06-08 at 7.18.44 PM.png![image.png](attachment:image.png)

# %% [markdown]
# # DESVIO

# %%
round(pow(0.2,0.5),4)
# Out:
# 0.4472

# %% [markdown]
# # a)Calcular  la  probabilidad  de  que  un  enlace  pertenezca  a  cada  una  de  las  categorías  definidas anteriormente.

# %% [markdown]
# # BAJA

# %%
CalcDistri.Normal_Menor(0.4, 0.5, 0.4472)
# Out:
# 0.41153

# %%
CalcDistri.Normal_CalcularZ(0.7, 0.5, 0.4472)
# Out:
# 0.44722719141323786

# %% [markdown]
# # MEDIA

# %%
CalcDistri.Normal_Entre(0.4,0.7,0.5, 0.4472)
# Out:
# 0.26112

# %% [markdown]
# # ALTA

# %%
CalcDistri.Normal_Mayor(0.7, 0.5, 0.4472)
# Out:
# 0.32736

# %% [markdown]
# # b)De los enlaces que pertenecen a la categoría alta ¿Qué porcentaje presenta una carga superior a 1,2?

# %%
round(CalcDistri.Normal_Mayor(1.2, 0.5, 0.4472),4)
# Out:
# 0.0588

# %%
CalcDistri.Normal_Mayor(0.7, 0.5, 0.4472)
# Out:
# 0.32736

# %% [markdown]
# # RESULTADO B)

# %%
round(CalcDistri.Normal_Mayor(1.2, 0.5, 0.4472),4)/CalcDistri.Normal_Mayor(0.7, 0.5, 0.4472)
# Out:
# 0.17961876832844575

# %% [markdown]
# # Si un enlace pertenece a la categoría moderada, la probabilidad de perder datos es de 0,15, mientras que, si pertenece a la categoría alta, dicha probabilidades de 0,75. Finalmente, si el enlace corresponde a la categoría baja, la probabilidad de pérdida de datos es de 0,1. Se pide:

# %% [markdown]
# # c)Calcular la probabilidad de que un enlace elegido al azar de la red pierda datos

# %%
0.75*0.32736+0.15*0.26112+0.1*0.41153
# Out:
# 0.325841

# %% [markdown]
# # Dado  que  un  enlace  tiene  pérdida  de  datos  ¿Cuál es  la  probabilidad  de  que  pertenezca  a  la categoría alta?

# %%
(0.75*0.32736) / 0.325841
# Out:
# 0.7534963371705832

# %% [markdown]
# Screen Shot 2020-06-08 at 8.07.29 PM.png![image.png](attachment:image.png)

# %%
3*0.5
# Out:
# 1.5

# %%
pow(0.2*3,0.5)
# Out:
# 0.7745966692414834

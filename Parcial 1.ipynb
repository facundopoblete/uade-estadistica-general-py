# %%
# Import de libs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import FuncionesIntervalos as fi
import FuncionesSinIntervalos as fsi
from fractions import Fraction

import importlib
importlib.reload(fi)
importlib.reload(fsi)
importlib.reload(plt)
# Out:
# <module 'matplotlib.pyplot' from '/Users/fpoblete/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# # 1
# Screen Shot 2020-04-20 at 6.41.14 PM.png![image.png](attachment:image.png)
#
# |         |A   |$\bar{A}$ |       |
# |---------|----|----------|-------|
# |B        |1/4 |1/6        | xx    |
# |$\bar{B}$|xxx |1/2        | xx    |
# |         |xxx |2/3        |  1    |
#
# # RESPUESTA =  1/6

# %% [markdown]
# # 2
#
# Screen Shot 2020-04-20 at 6.41.44 PM.png![image.png](attachment:image.png)
#
# # RESPUESTA 0.26

# %%
(2/5*4/5*2/4)+(3/5*1/5*2/4)+(2/5*1/5*2/4)
# Out:
# 0.26

# %% [markdown]
# # 3
# Screen Shot 2020-04-20 at 6.41.47 PM.png![image.png](attachment:image.png)
#
# # RESPUESTA 2/5

# %% [markdown]
# # 4
#
# Screen Shot 2020-04-20 at 6.41.49 PM.png![image.png](attachment:image.png)
#
# # RESPUESTA 1/6

# %%
(0.2*0.05) / (0.2*0.05 + 0.5*0.04 + 0.3*0.1)
# Out:
# 0.1666666666666667

# %% [markdown]
# # 5
#
# Screen Shot 2020-04-20 at 6.41.52 PM.png![image.png](attachment:image.png)
#
# # RESPUESTA 0.985875000000007

# %%
p5df = fi.CrearDataFrame(pd.Series([0.78,0.84,0.90,0.96,1.02,1.08,1.14]), pd.Series([0.84,0.90,0.96,1.02,1.08,1.14,1.20]), pd.Series([12,25,101,87,46,28,21]))

p5df
# Out:
#              X    LI    LS    f        fr      fr%    F    G    MP
# 0  0.78 - 0.84  0.78  0.84   12  0.037500   3.7500   12  320  0.81
# 1   0.84 - 0.9  0.84  0.90   25  0.078125   7.8125   37  308  0.87
# 2   0.9 - 0.96  0.90  0.96  101  0.315625  31.5625  138  283  0.93
# 3  0.96 - 1.02  0.96  1.02   87  0.271875  27.1875  225  182  0.99
# 4  1.02 - 1.08  1.02  1.08   46  0.143750  14.3750  271   95  1.05
# 5  1.08 - 1.14  1.08  1.14   28  0.087500   8.7500  299   49  1.11
# 6   1.14 - 1.2  1.14  1.20   21  0.065625   6.5625  320   21  1.17

# %%
fi.Promedio(p5df)
# Out:
# 0.9858750000000077

# %% [markdown]
# # 6
#
# Screen Shot 2020-04-20 at 6.41.55 PM.png![image.png](attachment:image.png)
#
# # RESPUESTA 0.9436

# %%
p6df = fi.CrearDataFrame(pd.Series([0.78,0.84,0.90,0.96,1.02,1.08,1.14]), pd.Series([0.84,0.90,0.96,1.02,1.08,1.14,1.20]), pd.Series([11,23,124,86,28,15,9]))

p6df
# Out:
#              X    LI    LS    f        fr        fr%    F    G    MP
# 0  0.78 - 0.84  0.78  0.84   11  0.037162   3.716216   11  296  0.81
# 1   0.84 - 0.9  0.84  0.90   23  0.077703   7.770270   34  285  0.87
# 2   0.9 - 0.96  0.90  0.96  124  0.418919  41.891892  158  262  0.93
# 3  0.96 - 1.02  0.96  1.02   86  0.290541  29.054054  244  138  0.99
# 4  1.02 - 1.08  1.02  1.08   28  0.094595   9.459459  272   52  1.05
# 5  1.08 - 1.14  1.08  1.14   15  0.050676   5.067568  287   24  1.11
# 6   1.14 - 1.2  1.14  1.20    9  0.030405   3.040541  296    9  1.17

# %%
0.90  + ((124-23)/((124-23)+(124-86))) * 0.06
# Out:
# 0.9435971223021583

# %% [markdown]
# # 7
#
# Screen Shot 2020-04-20 at 6.41.57 PM.png![image.png](attachment:image.png)
#
# # RESPUES 10/17

# %%
(2/3 * 0.6) / (1/3 * 0.84 + 2/3 * 0.6)
# Out:
# 0.5882352941176471

# %%
10/17
# Out:
# 0.5882352941176471

# %% [markdown]
# # 8
#
# Screen Shot 2020-04-20 at 6.42.01 PM.png![image.png](attachment:image.png)
#
# # RESPUESTA 0

# %% [markdown]
# # 9
#
# Screen Shot 2020-04-20 at 6.42.03 PM.png![image.png](attachment:image.png)
#
# # RESPUESTA 55/56

# %%
6/7 + 1/8
# Out:
# 0.9821428571428571

# %% [markdown]
# # 10
#
# Screen Shot 2020-04-20 at 7.46.01 PM.png![image.png](attachment:image.png)

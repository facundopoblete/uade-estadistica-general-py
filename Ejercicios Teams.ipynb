# %%
# Import de libs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import FuncionesIntervalos as fi
import FuncionesSinIntervalos as fsi
from fractions import Fraction

import importlib
importlib.reload(fi)
importlib.reload(fsi)
importlib.reload(plt)
# Out:
# <module 'matplotlib.pyplot' from '/Users/fpoblete/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# # EJERCICIO 1 TEAMS

# %% [markdown]
# # 3

# %%
df3 = pd.Series([5,3,6,6,9,7,1,2,6])

# %%
df3.mean()
# Out:
# 5.0

# %%
df3.median()
# Out:
# 6.0

# %%
df3.mode()
# Out:
# 0    6
# dtype: int64

# %% [markdown]
# # 6
#
# 1 - 1 - 2 - 3 - 2- 5 - 7 - 8 - 13 - 14 - 2 - 3 - 4 - 5 - 6 - 7 - 8

# %%
p6df = pd.Series([1,1,2,3,2,5,7,8,13,14,2,3,4,5,6,7,8])

# %%
p6df.median()
# Out:
# 5.0

# %% [markdown]
# # 7

# %%
p7df = fsi.CrearDataFrame(pd.Series([1,2,3,4,5,6,7]), pd.Series([1,3,5,8,5,2,1]))

p7df
# Out:
#    x  f    fr   fr%   F   G
# 0  1  1  0.04   4.0   1  25
# 1  2  3  0.12  12.0   4  24
# 2  3  5  0.20  20.0   9  21
# 3  4  8  0.32  32.0  17  16
# 4  5  5  0.20  20.0  22   8
# 5  6  2  0.08   8.0  24   3
# 6  7  1  0.04   4.0  25   1

# %% [markdown]
# # 8
# Screen Shot 2020-04-06 at 9.45.54 PM.png![image.png](attachment:image.png)

# %%
p8df = pd.Series([15,8,6,9,9,4,18,10,10,12,12,4,7,8,12,10,10,11,9,13,5,6,11,14,5,6,6,5,13,5])

# %%
# valido que sean 30
p8df.count()
# Out:
# 30

# %%
#media
p8df.mean()
# Out:
# 9.1

# %%
p8df.median()
# Out:
# 9.0

# %% [markdown]
# # 9
# Screen Shot 2020-04-06 at 9.41.50 PM.png![image.png](attachment:image.png)

# %%
p9df = fi.CrearDataFrame(pd.Series([20,30,40,50,60]), pd.Series([30,40,50,60,70]), pd.Series([6,7,4,8,5]))

# Mostrar tabla
p9df
# Out:
#          X  LI  LS  f        fr        fr%   F   G    MP
# 0  20 - 30  20  30  6  0.200000  20.000000   6  30  25.0
# 1  30 - 40  30  40  7  0.233333  23.333333  13  24  35.0
# 2  40 - 50  40  50  4  0.133333  13.333333  17  17  45.0
# 3  50 - 60  50  60  8  0.266667  26.666667  25  13  55.0
# 4  60 - 70  60  70  5  0.166667  16.666667  30   5  65.0

# %%
# Tamaño

p9df['f'].sum()
# Out:
# 30

# %%
# Varianza

fi.Varianza(p9df)
# Out:
# 203.33333333333331

# %%
fi.CoeficienteVariacion(p9df)
# Out:
# 31.924253188369313

# %% [markdown]
# # 10
# Screen Shot 2020-04-06 at 9.37.13 PM.png![image.png](attachment:image.png)

# %%
p10df = fi.CrearDataFrame(pd.Series([10,15,20,25,30]), pd.Series([15,20,25,30,35]), pd.Series([8,21,10,7,4]))

# Mostrar tabla
p10df
# Out:
#          X  LI  LS   f    fr   fr%   F   G    MP
# 0  10 - 15  10  15   8  0.16  16.0   8  50  12.5
# 1  15 - 20  15  20  21  0.42  42.0  29  42  17.5
# 2  20 - 25  20  25  10  0.20  20.0  39  21  22.5
# 3  25 - 30  25  30   7  0.14  14.0  46  11  27.5
# 4  30 - 35  30  35   4  0.08   8.0  50   4  32.5

# %%
fi.CoeficienteVariacion(p10df)
# Out:
# 28.654853021115173

# %% [markdown]
# # EJERCICIO 2 TEAMS

# %% [markdown]
# ### 1) Si P(A)=0,33 y P(B)=0,29. Si A y B son dos eventos mutuamente excluyentes entonces P(AUB) resulta:

# %%
0.33 + 0.29
# Out:
# 0.62

# %% [markdown]
# ### 2) De una urna que contiene 3 bolillas blancas, 2 bolillas negras y 4 verdes, se extraen 3 bolillas al azar sin reposición ¿Cuál es la probabilidad de obtener bolillas del mismo color?

# %%
(2/7 * 3/8 * 4/9) + (2/9 * 1/8 * 0/7) + (3/9 * 2/8 * 1/7)
# Out:
# 0.05952380952380952

# %% [markdown]
# Respuesta 5/84

# %% [markdown]
# ### 3) Suponiendo que A y B son dos eventos tales que la probabilidad de que ocurra A es 0,47, la probabilidad de que ocurra B es 0,25 y la probabilidad de que ocurran ambos es 0,4, entonces P(AUB) resulta:
#
# P(A) = 0.47
#
# P(B) = 0.25
#
# P($A \cap B$) = 0.4

# %%
0.47+0.25-0.4
# Out:
# 0.31999999999999995

# %% [markdown]
# ### 4) ![image.png](attachment:image.png)

# %% [markdown]
# P(B) = 0.5
#
# P(A | B) = 0.2
#
# 0.2 = P($A \cap B$) / P(B)
#
# 0.2 = P($A \cap B$) / 0.5
#
# 0.2 * 0.5 = P($A \cap B$)

# %%
0.2 * 0.5
# Out:
# 0.1

# %% [markdown]
# ### 5) Se lanza un dado una vez. Si se sabe que se obtuvo un número par ¿Cuál es la probabilidad de obtener un número mayor a 3? [CONSULTAR]

# %%
(1/6 * 2) / (1/6 * 3)
# Out:
# 0.6666666666666666

# %% [markdown]
# ### 6) ![image.png](attachment:image.png)

# %%
0.6 * 0.3
# Out:
# 0.18

# %% [markdown]
# ### 7) Se tienen dos cajas. La caja 1 contiene 4 bolillas blancas y 3 negras. La caja 2 contiene 3 bolillas blancas y 5 negras. Se selecciona una urna al azar y se extrae una bolilla que resultó ser blanca ¿Cuál es la probabilidad de que pertenezca a la caja 1?

# %%
(4/7 * 1/2) / (3/8 * 1/2 + 4/7 * 1/2)
# Out:
# 0.6037735849056604

# %% [markdown]
# Respuesta 32/53

# %% [markdown]
# ### 8) En una zona rural el 3 % de los habitantes contrae una enfermedad, que se detecta con un análisis el cual da positivo en el 90% de las personas enfermas y en el 8% de las sanas. Si se le practica el análisis a un individuo ¿ Cuál es la probabilidad de que esté enfermo y el análisis resulte positivo?

# %%
0.03 * 0.90
# Out:
# 0.027

# %% [markdown]
# ### 9) ![image.png](attachment:image.png)

# %% [markdown]
# P(A) = h
#
# P($A \cup B$) = 0.6
#
# P(B) = 0.2
#
# ---
#
# P($A \cup B$) + P($\bar{A} \cap \bar{B}$) = 1
#
# 0.6 + P($\bar{A} \cap \bar{B}$) = 1
#
# P($\bar{A} \cap \bar{B}$) = 1 - 0.6
#
# P($\bar{A} \cap \bar{B}$) = 0.4
#
# ---
#
# P($\bar{B}$) = 1 - 0.2
#
# P($\bar{B}$) = 0.8
#
# ---
#
# P($\bar{A} \cap \bar{B}$) = P($\bar{A}$) * P($\bar{B}$)
#
# 0.4 = P($\bar{A}$) * 0.8
#
# 0.4 / 0.8 = P($\bar{A}$)
#
# P($\bar{A}$) = 0.5
#
# P($A$) = 0.5

# %% [markdown]
# ### 10) ![image.png](attachment:image.png)

# %% [markdown]
# P($\bar{A}$) = 1/3
#
# P($A$) = 1 - 1/3
#
# ---
#
# P($\bar{B}$) = 1/2
#
# P($B$) = 1 - 1/2 = 0.5
#
# |         |A   |$\bar{A}$ |       |
# |---------|----|----------|-------|
# |B        |xxx |1/6        | xx    |
# |$\bar{B}$|1/3 |1/6        | 1/2    |
# |         |xxx |1/3        |  1    |
#
# Respuesta = 1/3
